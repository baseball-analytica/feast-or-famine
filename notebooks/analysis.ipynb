# %%
import pandas as pd
import pybaseball

pybaseball.cache.enable()

# %%
from typing import Any

data: dict[tuple[int, str], dict[str, Any]] = {}

# %%
from tqdm import tqdm
import time

for year in tqdm(range(1998, 2026)):
    print(f"starting year {year}")
    all_teams = pybaseball.team_pitching(year)["Team"].unique().tolist()

    for team in tqdm(all_teams):
        print(f"starting team {team}")
        time.sleep(1)
        team_data = pybaseball.schedule_and_record(year, team)

        team_data["rdiff"] = team_data["R"] - team_data["RA"]
        fof = team_data["rdiff"].abs().mean()
        rs = team_data["R"].mean()
        ra = team_data["RA"].mean()
        rdiff = team_data["rdiff"].mean()
        wpct = (team_data.loc[team_data["W/L"] == "W" | team_data["W/L"] == "W-wo", "W/L"].size) / team_data["W/L"].size

        data[(year, team)] = {
            "fof": fof,
            "rs": rs,
            "ra": ra,
            "rdiff": rdiff,
            "wpct": wpct,
        }

        print(f"finished team {team}")

    print(f"finished year {year}")

print("finished all years")
# Out:
#   0%|          | 0/28 [00:00<?, ?it/s]
# starting year 1998
# starting team ATL
# finished team ATL
# starting team HOU
# http://www.baseball-reference.com/teams/HOU/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team HOU
# starting team SDP
# http://www.baseball-reference.com/teams/SDP/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team SDP
# starting team NYM
# http://www.baseball-reference.com/teams/NYM/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team NYM
# starting team LAD
# http://www.baseball-reference.com/teams/LAD/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team LAD
# starting team NYY
# finished team NYY
# starting team PIT
# http://www.baseball-reference.com/teams/PIT/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team PIT
# starting team SFG
# http://www.baseball-reference.com/teams/SFG/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team SFG
# starting team BOS
# http://www.baseball-reference.com/teams/BOS/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team BOS
# starting team TOR
# http://www.baseball-reference.com/teams/TOR/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team TOR
# starting team STL
# http://www.baseball-reference.com/teams/STL/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team STL
# starting team TBD
# http://www.baseball-reference.com/teams/TBD/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team TBD
# starting team MON
# http://www.baseball-reference.com/teams/MON/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team MON
# starting team CIN
# http://www.baseball-reference.com/teams/CIN/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team CIN
# starting team CLE
# http://www.baseball-reference.com/teams/CLE/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team CLE
# starting team ANA
# http://www.baseball-reference.com/teams/ANA/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team ANA
# starting team CHC
# http://www.baseball-reference.com/teams/CHC/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team CHC
# starting team MIL
# http://www.baseball-reference.com/teams/MIL/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team MIL
# starting team ARI
# http://www.baseball-reference.com/teams/ARI/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team ARI
# starting team PHI
# http://www.baseball-reference.com/teams/PHI/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team PHI
# starting team BAL
# http://www.baseball-reference.com/teams/BAL/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team BAL
# starting team MIN
# http://www.baseball-reference.com/teams/MIN/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team MIN
# starting team OAK
# http://www.baseball-reference.com/teams/OAK/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team OAK
# starting team DET
# http://www.baseball-reference.com/teams/DET/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team DET
# starting team SEA
# http://www.baseball-reference.com/teams/SEA/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team SEA
# starting team TEX
# http://www.baseball-reference.com/teams/TEX/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team TEX
# starting team COL
# http://www.baseball-reference.com/teams/COL/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team COL
# starting team KCR
# http://www.baseball-reference.com/teams/KCR/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team KCR
# starting team FLA
# http://www.baseball-reference.com/teams/FLA/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team FLA
# starting team CHW
# http://www.baseball-reference.com/teams/CHW/1998-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# 100%|██████████| 30/30 [02:44<00:00,  5.48s/it]
#   4%|▎         | 1/28 [02:44<1:14:12, 164.90s/it]
# finished team CHW
# finished year 1998
# starting year 1999
# starting team ATL
# http://www.baseball-reference.com/teams/ATL/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team ATL
# starting team ARI
# http://www.baseball-reference.com/teams/ARI/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team ARI
# starting team HOU
# http://www.baseball-reference.com/teams/HOU/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team HOU
# starting team CIN
# http://www.baseball-reference.com/teams/CIN/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team CIN
# starting team BOS
# http://www.baseball-reference.com/teams/BOS/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team BOS
# starting team NYY
# finished team NYY
# starting team NYM
# http://www.baseball-reference.com/teams/NYM/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team NYM
# starting team PIT
# http://www.baseball-reference.com/teams/PIT/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team PIT
# starting team LAD
# http://www.baseball-reference.com/teams/LAD/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team LAD
# starting team SDP
# http://www.baseball-reference.com/teams/SDP/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team SDP
# starting team MON
# http://www.baseball-reference.com/teams/MON/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team MON
# starting team SFG
# http://www.baseball-reference.com/teams/SFG/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team SFG
# starting team STL
# http://www.baseball-reference.com/teams/STL/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team STL
# starting team OAK
# http://www.baseball-reference.com/teams/OAK/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team OAK
# starting team BAL
# http://www.baseball-reference.com/teams/BAL/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team BAL
# starting team ANA
# http://www.baseball-reference.com/teams/ANA/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team ANA
# starting team FLA
# http://www.baseball-reference.com/teams/FLA/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team FLA
# starting team CLE
# http://www.baseball-reference.com/teams/CLE/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team CLE
# starting team CHW
# http://www.baseball-reference.com/teams/CHW/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team CHW
# starting team TOR
# http://www.baseball-reference.com/teams/TOR/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team TOR
# starting team PHI
# http://www.baseball-reference.com/teams/PHI/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team PHI
# starting team MIN
# http://www.baseball-reference.com/teams/MIN/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team MIN
# starting team TBD
# http://www.baseball-reference.com/teams/TBD/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team TBD
# starting team TEX
# http://www.baseball-reference.com/teams/TEX/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team TEX
# starting team MIL
# http://www.baseball-reference.com/teams/MIL/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team MIL
# starting team DET
# http://www.baseball-reference.com/teams/DET/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team DET
# starting team SEA
# http://www.baseball-reference.com/teams/SEA/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team SEA
# starting team CHC
# http://www.baseball-reference.com/teams/CHC/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team CHC
# starting team KCR
# http://www.baseball-reference.com/teams/KCR/1999-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...
# starting team BAL
# http://www.baseball-reference.com/teams/BAL/2024-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team BAL
# starting team NYM
# http://www.baseball-reference.com/teams/NYM/2024-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team NYM
# starting team BOS
# http://www.baseball-reference.com/teams/BOS/2024-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team BOS
# starting team STL
# http://www.baseball-reference.com/teams/STL/2024-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team STL
# starting team CIN
# http://www.baseball-reference.com/teams/CIN/2024-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team CIN
# starting team SFG
# http://www.baseball-reference.com/teams/SFG/2024-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team SFG
# starting team PIT
# http://www.baseball-reference.com/teams/PIT/2024-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team PIT
# starting team MIN
# http://www.baseball-reference.com/teams/MIN/2024-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team MIN
# starting team TOR
# http://www.baseball-reference.com/teams/TOR/2024-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team TOR
# starting team WSN
# http://www.baseball-reference.com/teams/WSN/2024-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team WSN
# starting team OAK
# http://www.baseball-reference.com/teams/OAK/2024-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team OAK
# starting team TEX
# http://www.baseball-reference.com/teams/TEX/2024-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team TEX
# starting team LAA
# http://www.baseball-reference.com/teams/LAA/2024-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team LAA
# starting team ARI
# http://www.baseball-reference.com/teams/ARI/2024-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team ARI
# starting team CHW
# http://www.baseball-reference.com/teams/CHW/2024-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team CHW
# starting team MIA
# http://www.baseball-reference.com/teams/MIA/2024-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# finished team MIA
# starting team COL
# http://www.baseball-reference.com/teams/COL/2024-schedule-scores.shtml
# /home/charon-labs/baseball-analytica/feast-or-famine/.venv/lib/python3.12/site-packages/pybaseball/team_results.py:75: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].replace(r'^Unknown$', np.nan, regex=True, inplace = True) # make this a NaN so the column can benumeric
# 100%|██████████| 30/30 [02:53<00:00,  5.77s/it]
#  96%|█████████▋| 27/28 [1:18:08<02:54, 174.00s/it]
# finished team COL
# finished year 2024
# starting year 2025
# starting team TEX
# finished team TEX
# starting team MIL
# finished team MIL
# starting team SDP
# finished team SDP
# starting team CLE
# finished team CLE
# starting team BOS
# finished team BOS
# starting team KCR
# finished team KCR
# starting team PIT
# finished team PIT
# starting team PHI
# finished team PHI
# starting team CHC
# finished team CHC
# starting team SFG
# finished team SFG
# starting team HOU
# finished team HOU
# starting team CIN
# finished team CIN
# starting team SEA
# finished team SEA
# starting team NYY
# finished team NYY
# starting team TBR
# finished team TBR
# starting team LAD
# finished team LAD
# starting team DET
# finished team DET
# starting team NYM
# finished team NYM
# starting team TOR
# finished team TOR
# starting team CHW
# finished team CHW
# starting team STL
# finished team STL
# starting team ATL
# finished team ATL
# starting team ARI
# finished team ARI
# starting team MIN
# finished team MIN
# starting team MIA
# finished team MIA
# starting team BAL
# finished team BAL
# starting team ATH
# finished team ATH
# starting team LAA
# finished team LAA
# starting team WSN
# finished team WSN
# starting team COL
# 100%|██████████| 30/30 [00:30<00:00,  1.03s/it]
# 100%|██████████| 28/28 [1:18:40<00:00, 168.60s/it]
# finished team COL
# finished year 2025
# finished all years

# %%
print(data)
# Out:
# {(1998, 'ATL'): {'fof': np.float64(3.5), 'rs': np.float64(5.098765432098766), 'ra': np.float64(3.5864197530864197), 'rdiff': np.float64(1.5123456790123457), 'wpct': 0.6172839506172839}, (1998, 'HOU'): {'fof': np.float64(3.5308641975308643), 'rs': np.float64(5.395061728395062), 'ra': np.float64(3.8271604938271606), 'rdiff': np.float64(1.5679012345679013), 'wpct': 0.5617283950617284}, (1998, 'SDP'): {'fof': np.float64(3.0617283950617282), 'rs': np.float64(4.6234567901234565), 'ra': np.float64(3.919753086419753), 'rdiff': np.float64(0.7037037037037037), 'wpct': 0.5555555555555556}, (1998, 'NYM'): {'fof': np.float64(2.95679012345679), 'rs': np.float64(4.3580246913580245), 'ra': np.float64(3.9814814814814814), 'rdiff': np.float64(0.3765432098765432), 'wpct': 0.4876543209876543}, (1998, 'LAD'): {'fof': np.float64(2.8950617283950617), 'rs': np.float64(4.12962962962963), 'ra': np.float64(4.185185185185185), 'rdiff': np.
# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

mpl.rcParams["font.family"] = "monospace"

fig, ax = plt.subplots(figsize=(10, 6))

fig.suptitle("Feast-or-Famine Index vs. Runs Scored per Game", fontsize=16)

plt.title("All MLB team-seasons from 1998 through 2025; regular season only", pad=10)

ax.scatter(
    [d["fof"] for d in data.values()],
    [d["rs"] for d in data.values()],
    alpha=0.5,
    color="black"
)

ax.set_xlabel("FOF", fontsize=14)
ax.set_ylabel("RS/G", fontsize=14)

plt.yticks(
    np.linspace(2.5, 6.5, 17)
)

n = len(data)
trendline = np.polyfit([d["fof"] for d in data.values()], [d["rs"] for d in data.values()], 1)
trendline_fn = np.poly1d(trendline)
trendline_eq = f"y = {trendline[0]:.2f}x + {trendline[1]:.2f}"
r = np.corrcoef([d["fof"] for d in data.values()], [d["rs"] for d in data.values()])[0, 1]
r_squared = r**2

ax.plot(
    [d["fof"] for d in data.values()],
    trendline_fn([d["fof"] for d in data.values()]),
    color="red",
    label=trendline_eq,
    alpha=0.5
)

plt.show()

print(f"n: {n}")
print(f"trendline: {trendline_eq}")
print(f"R: {r:.2f}, R^2: {r_squared:.2f}")
# Out:
# n: 840
# trendline: y = 0.90x + 1.41
# R: 0.48, R^2: 0.23

# %%
fig.savefig("../assets/fof_rs_1998_2025.png")

# %%
nyy_2025 = pybaseball.schedule_and_record(2025, "NYY")
print(nyy_2025.head())
# Out:
#                Date   Tm Home_Away  Opp W/L     R   RA  Inn  W-L  Rank  \
# 1  Thursday, Mar 27  NYY      Home  MIL   W   4.0  2.0  9.0  1-0   1.0
# 2  Saturday, Mar 29  NYY      Home  MIL   W  20.0  9.0  9.0  2-0   1.0
# 3    Sunday, Mar 30  NYY      Home  MIL   W  12.0  3.0  9.0  3-0   1.0
# 4    Tuesday, Apr 1  NYY      Home  ARI   L   5.0  7.0  9.0  3-1   2.0
# 5  Wednesday, Apr 2  NYY      Home  ARI   L   3.0  4.0  9.0  3-2   3.0
#
#        GB     Win     Loss      Save  Time D/N  Attendance   cLI  Streak  \
# 1    Tied   Rodón  Peralta  Williams  3:08   D     46208.0   .90       1
# 2  up 0.5   Gómez   Cortés      None  3:05   D     46683.0   .91       2
# 3  up 1.0    Hill   Civale      None  2:41   D     41803.0   .96       3
# 4     0.5  Miller   Leiter       Puk  2:53   N     37482.0  1.00      -1
# 5     1.0  Gallen    Rodón       Puk  2:34   N     40558.0   .96      -2
#
#   Orig. Scheduled
# 1            None
# 2            None
# 3            None
# 4            None
# 5            None

# %%
print(nyy_2025["W/L"].value_counts())
# Out:
# W/L
# W       89
# L       61
# L-wo     7
# W-wo     5
# Name: count, dtype: int64
